# %%
import cv2
import mediapipe as mp

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Adarsh Singh\AppData\Local\Programs\Python\Python311\python.exe

# %%
import mediapipe as mp
print(mp.__file__)
print(mp.__version__)
print(hasattr(mp, "solutions"))
# Out:
# C:\Users\Adarsh Singh\AppData\Local\Programs\Python\Python311\Lib\site-packages\mediapipe\__init__.py
# 0.10.31
# False

# %%
import mediapipe
print(mediapipe.__file__)
# Out:
# C:\Users\Adarsh Singh\AppData\Local\Programs\Python\Python311\Lib\site-packages\mediapipe\__init__.py
